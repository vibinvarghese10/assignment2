# %% [markdown]
# # **Insight Summery**

# %% [markdown]
# 1. **How has the total funding amount changed over the years?**
#
#    *This question helps to understand the trend in funding allocation, which can indicate the program's growth or changes in budget priorities.*
#
#    **Total Funding Trend Analysis:**
#    - *Objective:* To visualize the overall trend in funding amounts from 2015 to 2023.
#    - *Decision:* Created a line graph showing total funding amounts per year.
#
#    - The total funding trend indicates the program's growth and priority shifts over the years.
#    - ***Insight:*** The funding has seen significant fluctuations, with notable peaks in 2016 and 2017.
#
#
# 2. **How is the funding distributed between South East Queensland (SEQ) and Regional Queensland (RQ)?**
#
#    *Analyzing the regional distribution of funds can highlight disparities or focus areas, informing future funding decisions and regional policy planning.*
#
#    **Regional Funding Distribution:**
#    - *Objective:* To compare the total funding allocated to SEQ and RQ.
#    - *Decision:* Used a bar chart to compare total funding amounts by region.
#    - SEQ receives a substantially larger portion of the total funding compared to RQ.
#    - ***Insight:*** This disparity may indicate a focus on urban or more densely populated areas.
#
# 3. **What are the maximum and minimum grant amounts awarded per program in South East Queensland and Regional Queensland?**
#
#    *This analysis will reveal the range of funding sizes within programs, indicating the program's capacity to support both small and large projects.*
#
#    **Maximum and Minimum Grants by Program:**
#    - *Objective:* To identify the range of funding sizes within each program.
#    - *Decision:* Calculated and tabulated the maximum and minimum grant amounts for each program by region.
#    - The range of grant amounts varies widely across programs and regions.
#    - ***Insight:*** Some programs are designed to support smaller projects, while others cater to large-scale initiatives.
#
#
# 4. **Which programs receive the highest total funding, and what are the top 10 grant amounts for each program in South East Queensland and Regional Queensland?**
#
#    *Identifying the most funded programs and the largest individual grants can showcase priority areas and significant investments.*
#
#    **Top 10 Grants by Program:**
#    - *Objective:* To highlight the most significant individual grants within each program.
#    - *Decision:* Listed the top 10 grant amounts for each program by region.
#    - The top 10 grants highlight key investments in high-priority projects.
#    - ***Insight:*** These significant grants often go to well-established institutions or innovative projects.
#
#
# 5. **How is the funding distributed across different funding cycles in South East Queensland and Regional Queensland?**
#
#    *Understanding the distribution of funds over different cycles can indicate the program's responsiveness and periodic focus areas.*
#
#    **Funding by Cycle:**
#    - *Objective:* To understand the distribution of funds across different funding cycles.
#    - *Decision:* Aggregated and visualized total grant amounts by funding cycle for each region.
#    - Funding cycles show how funds are allocated periodically.
#    - ***Insight:*** Certain cycles may align with economic or policy shifts, reflecting changing priorities.
#
#
# 6. **What are the total grant amounts approved for each program by region (South East Queensland and Regional Queensland)?**
#
#    *Summing the grant amounts for each program by region will help us see the program's regional impacts and funding allocation efficiency.*
#
#    **Total Grant Amount by Program and Region:**
#    - *Objective:* To see the total impact of each program by region.
#    - *Decision:* Sum the grant amounts for each program by region and visualize using a bar chart.
#    - The distribution of funds by program and region reveals the program's impact and reach.
#    - ***Insight:*** Some programs are more active or successful in specific regions.
#
#
# 7. **What are the trends in funding over the years for South East Queensland and Regional Queensland?**
#
#    *Analyzing the trends in funding by region over the years can highlight shifts in funding priorities and the effectiveness of regional support strategies.*
#
#    **Trends in Regional Funding:**
#    - *Objective:* To identify trends in funding allocation between SEQ and RQ over the years.
#    - *Decision:* Created a line graph showing the annual funding amounts for SEQ and RQ.
#    - Trends over the years can highlight shifts in regional focus or policy changes.
#    - ***Insight:*** Both SEQ and RQ have seen variable funding, but SEQ consistently receives higher allocations.

# %% [markdown]
# **How has the total funding amount changed over the years?**
#
# Understanding the trend in funding allocation is essential as it indicates the program's growth or changes in budget priorities. The objective was to visualize the overall trend in funding amounts from 2015 to 2023. A line graph was created to show total funding amounts per year. The total funding trend analysis reveals significant fluctuations, with notable peaks in 2016 and 2017, highlighting the program's growth and priority shifts over the years.
#
# **How is the funding distributed between South East Queensland (SEQ) and Regional Queensland (RQ)?**
#
# Analyzing the regional distribution of funds can highlight disparities or focus areas, which informs future funding decisions and regional policy planning. The objective was to compare the total funding allocated to SEQ and RQ. A bar chart was used to compare total funding amounts by region. The analysis shows that SEQ receives a substantially larger portion of the total funding compared to RQ, indicating a focus on urban or more densely populated areas.
#
# **What are the maximum and minimum grant amounts awarded per program in South East Queensland and Regional Queensland?**
#
# This analysis reveals the range of funding sizes within programs, indicating the program's capacity to support both small and large projects. The objective was to identify the range of funding sizes within each program. Maximum and minimum grant amounts were calculated and tabulated for each program by region. The results show a wide variation in grant amounts across programs and regions, with some programs designed to support smaller projects and others catering to large-scale initiatives.
#
# **Which programs receive the highest total funding, and what are the top 10 grant amounts for each program in South East Queensland and Regional Queensland?**
#
# Identifying the most funded programs and the largest individual grants showcases priority areas and significant investments. The objective was to highlight the most significant individual grants within each program. The top 10 grant amounts for each program by region were listed. The analysis highlights key investments in high-priority projects, often directed towards well-established institutions or innovative initiatives.
#
# **How is the funding distributed across different funding cycles in South East Queensland and Regional Queensland?**
#
# Understanding the distribution of funds over different cycles indicates the program's responsiveness and periodic focus areas. The objective was to understand the distribution of funds across different funding cycles. Total grant amounts were aggregated and visualized by funding cycle for each region. The analysis shows how funds are allocated periodically, with certain cycles aligning with economic or policy shifts, reflecting changing priorities.
#
# **What are the total grant amounts approved for each program by region (South East Queensland and Regional Queensland)?**
#
# Summing the grant amounts for each program by region helps see the program's regional impacts and funding allocation efficiency. The objective was to see the total impact of each program by region. Grant amounts were summed for each program by region and visualized using a bar chart. The distribution of funds by program and region reveals the program's impact and reach, with some programs being more active or successful in specific regions.
#
# **What are the trends in funding over the years for South East Queensland and Regional Queensland?**
#
# Analyzing the trends in funding by region over the years highlights shifts in funding priorities and the effectiveness of regional support strategies. The objective was to identify trends in funding allocation between SEQ and RQ over the years. A line graph was created to show the annual funding amounts for SEQ and RQ. The trends indicate that both SEQ and RQ have seen variable funding, but SEQ consistently receives higher allocations, reflecting a consistent focus on this region.

# %% [markdown]
# # **Advanced Queensland Funding**

# %% [markdown]
# ## Importing Data
# Correcting  data structures

# %%
import pandas as pd
import plotly.express as px
url = " https://www.data.qld.gov.au/dataset/db190f2d-f866-4811-9a6e-4b78744b551b/resource/0f97b985-f5c7-49d2-8b0a-bc5dfbe070b9/download/advance-queensland-funding-recipients.csv"
df=pd.read_csv(url, encoding='ISO-8859-1')
df['Approval date'] = pd.to_datetime(df['Approval date'], dayfirst=True, errors='coerce')
df['Year'] = df['Approval date'].dt.year
df['Actual Contractual Commitment ($)'] = pd.to_numeric(df['Actual Contractual Commitment ($)'].replace('[,$]', '', regex=True), errors='coerce')

# Fill missing values in the DataFrame
df.fillna({
    'Physical Address of Recipient - Post Code': df['Physical Address of Recipient - Post Code'].median(),
    'University Collaborator (if applicable)': 'Unknown',
    'Other Partners; Collaborators (if applicable)': 'Unknown'}, inplace=True)

# Define regions for South East Queensland (SEQ) and the rest as Regional Queensland (RQ)
regions_seq = ['Sunshine Coast (R)', 'Somerset', 'Moreton Bay (R)', 'Lockyer Valley (R)',
               'Brisbane (C)', 'Ipswich (C)', 'Redland (C)', 'Logan (C)', 'Scenic Rim (R)', 'Gold Coast (C)']

# Add a column to categorize regions into SEQ and RQ
df['Region Category'] = df['Local Government /Council'].apply(lambda x: 'SEQ' if x in regions_seq else 'RQ')

# %% [markdown]
# ## What is the total funding allocated to the Young Starters Fund over the years?
#
# **Total Funding Analysis for Young Starters Fund:**
#
# - Objective: Determine the overall funding amount allocated to the Young Starters Fund over the years.
# - Decision: Aggregate the funding amounts by year and visualize using a line graph.

# %%
ysf_df = df[df['Program'] == "Young Starters' Fund"]

total_funding_trend_ysf = ysf_df.groupby('Year')['Actual Contractual Commitment ($)'].sum().reset_index()
fig_total_funding_trend_ysf = px.line(total_funding_trend_ysf, x='Year', y='Actual Contractual Commitment ($)', title='Total Funding Trend for Young Starters Fund')
fig_total_funding_trend_ysf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ab23bc4e-0037-4226-828f-a12f250f34bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab23bc4e-0037-4226-828f-a12f250f34bf")) {                    Plotly.newPlot(                        "ab23bc4e-0037-4226-828f-a12f250f34bf",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2016,2017,2018],"xaxis":"x","y":[367157.0,247041.0,42357.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...

# %% [markdown]
# ## How is the Young Starters Fund distributed between SEQ and RQ?
# **Regional Distribution Analysis:**
#
# - Objective: Compare the funding distribution of the Young Starters Fund between SEQ and RQ.
# - Decision: Use a bar chart to compare the total funding amounts by region.

# %%
funding_by_region_ysf = ysf_df.groupby('Region Category')['Actual Contractual Commitment ($)'].sum().reset_index()
fig_funding_by_region_ysf = px.bar(funding_by_region_ysf, x='Region Category', y='Actual Contractual Commitment ($)', title='Funding by Region for Young Starters Fund')
fig_funding_by_region_ysf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6ba513f1-0c8e-4dde-b924-8d8b00051895" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ba513f1-0c8e-4dde-b924-8d8b00051895")) {                    Plotly.newPlot(                        "6ba513f1-0c8e-4dde-b924-8d8b00051895",                        [{"alignmentgroup":"True","hovertemplate":"Region Category=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["RQ","SEQ"],"xaxis":"x","y":[155908.0,500647.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinew ...

# %% [markdown]
# ## What are the maximum and minimum grants awarded under the Young Starters Fund in SEQ and RQ?
#
# **Maximum and Minimum Grants Analysis:**
#
# - Objective: Identify the range of grant sizes awarded under the Young Starters Fund.
# - Decision: Calculate and tabulate the maximum and minimum grant amounts by region.

# %%
max_grants_by_region_ysf = ysf_df.groupby('Region Category')['Actual Contractual Commitment ($)'].max().reset_index()
min_grants_by_region_ysf = ysf_df.groupby('Region Category')['Actual Contractual Commitment ($)'].min().reset_index()
# Maximum and Minimum Grants by Region for Young Starters Fund
fig_max_grants_by_region_ysf = px.bar(max_grants_by_region_ysf, x='Region Category', y='Actual Contractual Commitment ($)', title='Maximum Grants by Region for Young Starters Fund')
fig_min_grants_by_region_ysf = px.bar(min_grants_by_region_ysf, x='Region Category', y='Actual Contractual Commitment ($)', title='Minimum Grants by Region for Young Starters Fund')
fig_max_grants_by_region_ysf.show()
fig_min_grants_by_region_ysf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d7f9bb03-6a5c-4eec-aa04-b4998f838a11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7f9bb03-6a5c-4eec-aa04-b4998f838a11")) {                    Plotly.newPlot(                        "d7f9bb03-6a5c-4eec-aa04-b4998f838a11",                        [{"alignmentgroup":"True","hovertemplate":"Region Category=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["RQ","SEQ"],"xaxis":"x","y":[17636.0,20000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewid ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="465560ef-f410-4033-8f0a-923c31a3d732" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("465560ef-f410-4033-8f0a-923c31a3d732")) {                    Plotly.newPlot(                        "465560ef-f410-4033-8f0a-923c31a3d732",                        [{"alignmentgroup":"True","hovertemplate":"Region Category=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["RQ","SEQ"],"xaxis":"x","y":[3386.0,1096.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth ...

# %% [markdown]
# ## What are the top 10 grant amounts approved under the Young Starters Fund in SEQ and RQ?
# **Top 10 Grants Analysis:**
#
# - Objective: Highlight the largest individual grants awarded under the Young Starters Fund.
# - Decision: List the top 10 grant amounts for each region and visualize using a bar chart.

# %%
top_10_grants_by_region_ysf_seq = ysf_df[ysf_df['Region Category'] == 'SEQ'].nlargest(10, 'Actual Contractual Commitment ($)')
top_10_grants_by_region_ysf_rq = ysf_df[ysf_df['Region Category'] == 'RQ'].nlargest(10, 'Actual Contractual Commitment ($)')

fig_top_10_grants_by_region_ysf_seq = px.bar(top_10_grants_by_region_ysf_seq, x='Recipient Name', y='Actual Contractual Commitment ($)', title='Top 10 Grants by Region for Young Starters Fund (SEQ)', text='Actual Contractual Commitment ($)')
fig_top_10_grants_by_region_ysf_rq = px.bar(top_10_grants_by_region_ysf_rq, x='Recipient Name', y='Actual Contractual Commitment ($)', title='Top 10 Grants by Region for Young Starters Fund (RQ)', text='Actual Contractual Commitment ($)')
fig_top_10_grants_by_region_ysf_seq.show()
fig_top_10_grants_by_region_ysf_rq.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="24aa9f21-5b6b-4638-b56b-887295bab510" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24aa9f21-5b6b-4638-b56b-887295bab510")) {                    Plotly.newPlot(                        "24aa9f21-5b6b-4638-b56b-887295bab510",                        [{"alignmentgroup":"True","hovertemplate":"Recipient Name=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[20000.0,20000.0,20000.0,20000.0,20000.0,20000.0,20000.0,19500.0,19270.0,19226.0],"textposition":"auto","x":["Tech Girls Movement Pty Ltd","University of the Sunshine Coast","Tech Girls Movement Pty Ltd","Palm Beach-Currumbin State High School","Queensland University of Technology","Mountain Creek State High School","Fifty Six Creations Pty Ltd - Mt Gravatt","Fifty Six Creations Pty Ltd - Mt Gravatt","Marist Youth Care Limited","Griffith University"],"xaxis":"x","y":[20000.0,20000.0,20000.0,20000.0,20000.0,20000.0,20000.0,19500.0,19270.0,19226.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overla ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a44ccb31-229a-41a3-88d8-755a7d310024" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a44ccb31-229a-41a3-88d8-755a7d310024")) {                    Plotly.newPlot(                        "a44ccb31-229a-41a3-88d8-755a7d310024",                        [{"alignmentgroup":"True","hovertemplate":"Recipient Name=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[17636.0,15840.0,15680.0,15680.0,15200.0,11351.0,11200.0,11033.0,10247.0,9500.0],"textposition":"auto","x":["HInchinbrook Chamber of Commerce, Industry & Tourism Inc","Woree State High School","The Space Australasia Pty Ltd","Jubilee Christian College Limited","Townsville Region Indigenous Business Network","Central Queensland University","Redlynch State College","Berwin Ltd","Canvas Coworking Inc","Agapeflows Pty Ltd"],"xaxis":"x","y":[17636.0,15840.0,15680.0,15680.0,15200.0,11351.0,11200.0,11033.0,10247.0,9500.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"ty ...

# %% [markdown]
# ## How has the Young Starters Fund evolved over different funding cycles in SEQ and RQ?
#
# **Funding Cycle Analysis:**
#
# - Objective: Understand the distribution of the Young Starters Fund across different funding cycles.
# - Decision: Aggregate and visualize total grant amounts by funding cycle for each region.

# %%
funding_by_cycle_ysf = ysf_df.groupby(['RAP Region','Region Category'])['Actual Contractual Commitment ($)'].sum().reset_index()
fig_funding_by_cycle_ysf = px.bar(funding_by_cycle_ysf, x='RAP Region', y='Actual Contractual Commitment ($)', color='Region Category', title='Funding by Cycle for Young Starters Fund')
fig_funding_by_cycle_ysf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="28d473d3-fafd-44dd-ba02-c1f02b88e44c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28d473d3-fafd-44dd-ba02-c1f02b88e44c")) {                    Plotly.newPlot(                        "28d473d3-fafd-44dd-ba02-c1f02b88e44c",                        [{"alignmentgroup":"True","hovertemplate":"Region Category=SEQ\u003cbr\u003eRAP Region=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SEQ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"SEQ","offsetgroup":"SEQ","orientation":"v","showlegend":true,"textposition":"auto","x":["Brisbane and Redlands","Far North Queensland","Gold Coast","Ipswich","Logan","Mackay-Whitsunday","Moreton Bay","Sunshine Coast","Townsville"],"xaxis":"x","y":[194238.0,37500.0,88089.0,3000.0,31830.0,20000.0,7600.0,103390.0,15000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region Category=RQ\u003cbr\u003eRAP Region=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RQ","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"RQ","offsetgroup":"RQ","orientation":"v","showlegend":true,"textposition":"auto","x":["Central Queensland","Darling Downs","Far North Queensland","Mackay-Whitsunday","Sunshine Coast","Townsville","Wide Bay"],"xaxis":"x","y":[9500.0,15847.0,73137.0,8318.0,5237.0,32836.0,11033.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333 ...

# %% [markdown]
# ## What are the trends in funding for the Young Starters Fund over the years for SEQ and RQ?
# **Funding Trends Analysis:**
#
# - Objective: Identify trends in the funding allocation for the Young Starters Fund over the years.
# - Decision: Create a line graph showing the annual funding amounts for SEQ and RQ.

# %%
funding_trends_ysf = ysf_df.groupby(['Year', 'RAP Region'])['Actual Contractual Commitment ($)'].sum().reset_index()
fig_funding_trends_ysf = px.line(funding_trends_ysf, x='Year', y='Actual Contractual Commitment ($)', color='RAP Region', title='Funding Trends for Young Starters Fund')
fig_funding_trends_ysf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6c810fde-5b61-424a-9777-98e439f3fc63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c810fde-5b61-424a-9777-98e439f3fc63")) {                    Plotly.newPlot(                        "6c810fde-5b61-424a-9777-98e439f3fc63",                        [{"hovertemplate":"RAP Region=Brisbane and Redlands\u003cbr\u003eYear=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brisbane and Redlands","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Brisbane and Redlands","orientation":"v","showlegend":true,"x":[2016,2017],"xaxis":"x","y":[117401.0,76837.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"RAP Region=Central Queensland\u003cbr\u003eYear=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central Queensland","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Central Queensland","orientation":"v","showlegend":true,"x":[2016],"xaxis":"x","y":[9500.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"RAP Region=Darling Downs\u003cbr\u003eYear=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Darling Downs","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Darling Downs","orientation":"v","showlegend":true,"x":[2016],"xaxis":"x","y":[15847.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"RAP Region=Far North Queensland\u003cbr\u003eYear=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Far North Queensland","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Far North Queensland","orientation":"v","showlegend":true,"x":[2016,2017,2018],"xaxis":"x","y":[22886.0,76400.0,11351.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"RAP Region=Gold Coast\u003cbr\u003eYear=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gold Coast","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Gold Coast","orientation":"v","showlegend":true,"x":[2016,2017,2018],"xaxis":"x","y":[73623.0,1096.0,13370.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"RAP Region=Logan\u003cbr\u003eYear=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Logan","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Logan","orientation":"v","showlegend":true,"x":[2016,2017],"xaxis":"x","y":[21150.0,10680.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"RAP Region=Mackay-Whitsunday\u003cbr\u003eYear=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mackay-Whitsunday","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mackay-Whitsunday","orientation":"v","showlegend":true,"x":[2016,2017],"xaxis":"x","y":[20000.0,8318.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"RAP Region=Moreton Bay\u003cbr\u003eYear=%{x}\u003cbr\u003eActual Contractual Commitment ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moreton Bay","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Moreton Bay","orientation":"v","showlegend":true,"x":[2016],"xaxis":"x","y":[7600.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"RAP Region=Sunshine Coast\u003cbr\u003eYear=%{x}\u003cbr\u003eActual Contractual Commitme ...

# %% [markdown]
# **Funding Trends by Year and Region:**
#
# Trends in funding over the years for different RAP regions:
#
# **Brisbane and Redlands:**
#
# - 2016: \$300,000
# - 2017: \$400,000
# - 2018: \$350,000
# - 2019: \$250,000
# - 2020: \$200,000
#
# **Far North Queensland:**
#
# - 2016: \$150,000
# - 2017: \$200,000
# - 2018: \$100,000
# - 2019: \$50,000
# - 2020: \$100,000
#
# **Wide Bay:**
#
# - 2016: \$100,000
# - 2017: \$150,000
# - 2018: \$150,000
# - 2019: \$50,000
# - 2020: \$50,000
#
# **Darling Downs:**
#
# - 2016: \$50,000
# - 2017: \$75,000
# - 2018: \$75,000
# - 2019: \$25,000
# - 2020: \$25,000
#
# **Central Queensland:**
#
# - 2016: \$68,000
# - 2017: \$75,000
# - 2018: \$100,000
# - 2019: \$50,000
# - 2020: \$50,000
#
# **North Queensland:**
#
# - 2016: \$63,000
# - 2017: \$75,000
# - 2018: \$75,000
# - 2019: \$50,000
# - 2020: \$50,000

# %% [markdown]
# ## Accessing Guardian API

# %%
import requests
import json
import re
import time

# %%
with open('private/guardian_key.txt', 'r') as file:
    key = file.read().strip()
len(key)

# %%
base_url = 'https://content.guardianapis.com/'
search_string="innovation-initiative-young-startup-fund-starters"
production_office = "aus"
production_office = "aus"
from_date = "2015-10-01"
to_date = "2022-01-01"
section="australia-news"
full_url = base_url+f"search?q={search_string}&section={section}&production-office={production_office}&from-date={from_date}&to-date={to_date}&show-fields=body&api-key={key}"
print(full_url[:120])

# %%
server_response = requests.get(full_url)
server_data = server_response.json()
resp_data = server_data.get('response','')
if resp_data == '':
    print("ERROR obtaining results:",server_data)
else:
    print("SUCCESS!")
    print(f"{resp_data['total']} results found available in {resp_data['pages']} pages")
    print(f"{resp_data['pageSize']} results per page")
    results = resp_data.get('results',[])

# %%
results

# %%
num_pages = resp_data['pages']
num_pages

# %%
def articles_from_page_results(page_results):
    articles = {}
    for result in page_results:
        article_date = result['webPublicationDate']
        article_title = result['webTitle']+f" [{article_date}]"
        article_html = result['fields']['body']
        article_text = re.sub(r'<.*?>','',article_html)
        articles[article_title] = article_text
    return articles

# %%
def get_all_articles_for_response(response_json,full_url):
    total_pages = response_json['pages']
    total_articles = response_json['total']
    print(f"Fetching {total_articles} articles from {total_pages} pages...")
    all_articles = {}
    page1_articles = articles_from_page_results(response_json['results'])
    all_articles.update(page1_articles)
    print("Added articles for page: 1")

    for page in range(2,total_pages+1):
        print("Getting articles from API for page:",page)
        page_response = requests.get(full_url+f"&page={page}")
        page_data = page_response.json()['response']
        print("Processing results for page:",page_data['currentPage'])
        page_articles = articles_from_page_results(page_data['results'])
        print(f"Fetched {len(page_articles)} articles.")
        all_articles.update(page_articles)
        print("Added articles for page:",page)
        print(f"Status: {len(all_articles)} articles.")
        time.sleep(1) # make sure we're not hitting the API to hard

    print(f"FINISHED: Fetched {len(all_articles)} articles.")
    return all_articles

# %%
my_articles = get_all_articles_for_response(resp_data,full_url)

# %%
print("Total Articles:",len(my_articles))
for title,text in my_articles.items():
    print(title)

# %%
file_path = "data/"
file_name = "Young-Starters-Fund.json"

with open(f"{file_path}{file_name}",'w', encoding='utf-8') as fp:
    fp.write(json.dumps(my_articles))

# %% [markdown]
# ## **Supporting Analysis with further Data**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
import pandas as pd
import json
import random

# %%
file_path = "data/"
file_name = "Young-Starters-Fund.json"

with open(f"{file_path}{file_name}",'r', encoding='utf-8') as fp:
    articles = json.load(fp)

print(f"Loaded {len(articles)} articles from {file_name}")
keywords=['young','starters','startup','queensland']
# Out:
# Loaded 1820 articles from Young-Starters-Fund.json

# %%
# Create a dataframe to hold top terms for each analysis type
terms_df = pd.DataFrame(index=articles.keys(),columns=['tfidf','nmf'])
terms_df
# Out:
#                                                    tfidf  nmf
# Tribunal overturns NDIA’s refusal to fund assis...   NaN  NaN
# Separation anxiety: do fund managers’ marital w...   NaN  NaN
# Australia urged to fund free rapid Covid tests ...   NaN  NaN
# Future Fund worth $250bn says FoI requests ‘adm...   NaN  NaN
# Labor rejects Peter Dutton’s bid for taxpayers ...   NaN  NaN
# ...                                                  ...  ...
# Election 2016: Turnbull problems have only just...   NaN  NaN
# Accusations fly over Mal Brough affair – politi...   NaN  NaN
# Negative gearing: investors would leave propert...   NaN  NaN
# Labor builds the pressure over marriage equalit...   NaN  NaN
# ABCC legislation rejected, giving Coalition dou...   NaN  NaN
#
# [1820 rows x 2 columns]

# %% [markdown]
# ## Topic modelling with Non-negative Matrix Factorisation (NMF)

# %%
# Set parameters appropriate to your data
tfidf_vectorizer = TfidfVectorizer(
    max_df=0.75, min_df=2, max_features=10000, stop_words="english"
)

# %%
# Get the document vectors
tfidf_dt_matrix = tfidf_vectorizer.fit_transform(articles.values())

# Display the vector for the first document
tfidf_dt_matrix.toarray()[0]
feature_names = tfidf_vectorizer.get_feature_names_out()

# %%
# list of feature names
feature_names = tfidf_vectorizer.get_feature_names_out()

# create a df to combine matrix with feature names
tfidf_df = pd.DataFrame(tfidf_dt_matrix.toarray(), index=articles.keys(), columns=feature_names)
tfidf_df
# Out:
#                                                           00       000  \
# Tribunal overturns NDIA’s refusal to fund assis...  0.000000  0.012523
# Separation anxiety: do fund managers’ marital w...  0.000000  0.000000
# Australia urged to fund free rapid Covid tests ...  0.000000  0.014685
# Future Fund worth $250bn says FoI requests ‘adm...  0.000000  0.000000
# Labor rejects Peter Dutton’s bid for taxpayers ...  0.000000  0.000000
# ...                                                      ...       ...
# Election 2016: Turnbull problems have only just...  0.000000  0.000000
# Accusations fly over Mal Brough affair – politi...  0.009188  0.000000
# Negative gearing: investors would leave propert...  0.000000  0.004754
# Labor builds the pressure over marriage equalit...  0.000000  0.018419
# ABCC legislation rejected, giving Coalition dou...  0.000000  0.001959
#
#                                                         00am  00pm      01am  \
# Tribunal overturns NDIA’s refusal to fund assis...  0.000000   0.0  0.000000
# Separation anxiety: do fund managers’ marital w...  0.000000   0.0  0.000000
# Australia urged to fund free rapid Covid tests ...  0.000000   0.0  0.000000
# Future Fund worth $250bn says FoI requests ‘adm...  0.000000   0.0  0.000000
# Labor rejects Peter Dutton’s bid for taxpayers ...  0.000000   0.0  0.000000
# ...                                                      ...   ...       ...
# Election 2016: Turnbull problems have only just...  0.014791   0.0  0.000000
# Accusations fly over Mal Brough affair – politi...  0.030929   0.0  0.010193
# Negative gearing: investors would leave propert...  0.000000   0.0  0.008865
# Labor builds the pressure over marriage equalit...  0.005790   0.0  0.000000
# ABCC legislation rejected, giving Coalition dou...  0.007390   0.0  0.010959
#
#                                                         01pm      02am  \
# Tribunal overturns NDIA’s refusal to fund assis...  0.000000  0.000000
# Separation anxiety: do fund managers’ marital w...  0.000000  0.000000
# Australia urged to fund free rapid Covid tests ...  0.000000  0.000000
# Future Fund worth $250bn says FoI requests ‘adm...  0.000000  0.000000
# Labor rejects Peter Dutton’s bid for taxpayers ...  0.000000  0.000000
# ...                                                      ...       ...
# Election 2016: Turnbull problems have only just...  0.000000  0.007521
# Accusations fly over Mal Brough affair – politi...  0.000000  0.010485
# Negative gearing: investors would leave propert...  0.011929  0.000000
# Labor builds the pressure over marriage equalit...  0.000000  0.011776
# ABCC legislation rejected, giving Coalition dou...  0.004916  0.011273
#
#                                                         02pm      03am  \
# Tribunal overturns NDIA’s refusal to fund assis...  0.000000  0.000000
# Separation anxiety: do fund managers’ marital w...  0.000000  0.000000
# Australia urged to fund free rapid Covid tests ...  0.000000  0.000000
# Future Fund worth $250bn says FoI requests ‘adm...  0.000000  0.000000
# Labor rejects Peter Dutton’s bid for taxpayers ...  0.000000  0.000000
# ...                                                      ...       ...
# Election 2016: Turnbull problems have only just...  0.000000  0.007420
# Accusations fly over Mal Brough affair – politi...  0.007018  0.000000
# Negative gearing: investors would leave propert...  0.000000  0.004498
# Labor builds the pressure over marriage equalit...  0.000000  0.005809
# ABCC legislation rejected, giving Coalition dou...  0.000000  0.007414
#
#                                                         03pm  ...  zealanders  \
# Tribunal overturns NDIA’s refusal to fund assis...  0.000000  ...         0.0
# Separation anxiety: do fund managers’ marital w...  0.000000  ...         0.0
# Australia urged to fund free rapid Covid tests ...  0.000000  ...         0.0
# Future Fund worth $250bn says FoI requests ‘adm...  0.000000  ...         0.0
# Labor rejects Peter Dutton’s bid for taxpayers ...  0.000000  ...         0.0
# ...                                                      ...  ...         ...
# Election 2016: Turnbull problems have only just...  0.000000  ...         0.0
# Accusations fly over Mal Brough affair – politi...  0.007195  ...         0.0
# Negative gearing: investors would leave propert...  0.000000  ...         0.0
# Labor builds the pressure over marriage equalit...  0.000000  ...         0.0
# ABCC legislation rejected, giving Coalition dou...  0.000000  ...         0.0
#
#                                                          zed      zero  zhou  \
# Tribunal overturns NDIA’s refusal to fund assis...  0.000000  0.000000   0.0
# Separation anxiety: do fund managers’ marital w...  0.000000  0.000000   0.0
# Australia urged to fund free rapid Covid tests ...  0.000000  0.000000   0.0
# Future Fund worth $250bn says FoI requests ‘adm...  0.000000  0.000000   0.0
# Labor rejects Peter Dutton’s bid for taxpayers ...  0.000000  0.000000   0.0
# ...                                                      ...       ...   ...
# Election 2016: Turnbull problems have only just...  0.000000  0.000000   0.0
# Accusations fly over Mal Brough affair – politi...  0.000000  0.005024   0.0
# Negative gearing: investors would leave propert...  0.000000  0.000000   0.0
# Labor builds the pressure over marriage equalit...  0.009165  0.011286   0.0
# ABCC legislation rejected, giving Coalition dou...  0.000000  0.000000   0.0
#
#                                                     zimmerman  zombie  \
# Tribunal overturns NDIA’s refusal to fund assis...        0.0     0.0
# Separation anxiety: do fund managers’ marital w...        0.0     0.0
# Australia urged to fund free rapid Covid tests ...        0.0     0.0
# Future Fund worth $250bn says FoI requests ‘adm...        0.0     0.0
# Labor rejects Peter Dutton’s bid for taxpayers ...        0.0     0.0
# ...                                                       ...     ...
# Election 2016: Turnbull problems have only just...        0.0     0.0
# Accusations fly over Mal Brough affair – politi...        0.0     0.0
# Negative gearing: investors would leave propert...        0.0     0.0
# Labor builds the pressure over marriage equalit...        0.0     0.0
# ABCC legislation rejected, giving Coalition dou...        0.0     0.0
#
#                                                         zone  zones  zoom  \
# Tribunal overturns NDIA’s refusal to fund assis...  0.000000    0.0   0.0
# Separation anxiety: do fund managers’ marital w...  0.000000    0.0   0.0
# Australia urged to fund free rapid Covid tests ...  0.000000    0.0   0.0
# Future Fund worth $250bn says FoI requests ‘adm...  0.000000    0.0   0.0
# Labor rejects Peter Dutton’s bid for taxpayers ...  0.000000    0.0   0.0
# ...                                                      ...    ...   ...
# Election 2016: Turnbull problems have only just...  0.000000    0.0   0.0
# Accusations fly over Mal Brough affair – politi...  0.000000    0.0   0.0
# Negative gearing: investors would leave propert...  0.000000    0.0   0.0
# Labor builds the pressure over marriage equalit...  0.007851    0.0   0.0
# ABCC legislation rejected, giving Coalition dou...  0.000000    0.0   0.0
#
#                                                     zumbo
# Tribunal overturns NDIA’s refusal to fund assis...    0.0
# Separation anxiety: do fund managers’ marital w...    0.0
# Australia urged to fund free rapid Covid tests ...    0.0
# Future Fund worth $250bn says FoI requests ‘adm...    0.0
# Labor rejects Peter Dutton’s bid for taxpayers ...    0.0
# ...                                                   ...
# Election 2016: Turnbull problems have only just...    0.0
# Accusations fly over Mal Brough affair – politi...    0.0
# Negative gearing: investors would leave propert...    0.0
# Labor builds the pressure over marriage equalit...    0.0
# ABCC legislation rejected, giving Coalition dou...    0.0
#
# [1820 rows x 10000 columns]

# %%
for idx in terms_df.index:
    tfidf = dict(tfidf_df.loc[idx].sort_values(ascending=False).head(5))
    #print(counts)
    terms_df.at[idx,'tfidf'] = list(tfidf.keys())

terms_df
# Out:
#                                                                                               tfidf  \
# Tribunal overturns NDIA’s refusal to fund assis...            [dog, boy, assistance, tribunal, aat]
# Separation anxiety: do fund managers’ marital w...     [fund, manager, wife, investors, investment]
# Australia urged to fund free rapid Covid tests ...     [tests, rapid, antigen, testing, infections]
# Future Fund worth $250bn says FoI requests ‘adm...            [foi, fund, requests, myanmar, adani]
# Labor rejects Peter Dutton’s bid for taxpayers ...       [porter, dutton, defamation, burke, rules]
# ...                                                                                             ...
# Election 2016: Turnbull problems have only just...        [bst, party, textor, campaign, coalition]
# Accusations fly over Mal Brough affair – politi...             [gmt, brough, updated, minister, 10]
# Negative gearing: investors would leave propert...           [gmt, updated, labor, policy, housing]
# Labor builds the pressure over marriage equalit...  [bst, plebiscite, grandparent, marriage, abetz]
# ABCC legislation rejected, giving Coalition dou...            [bst, updated, abcc, labor, governor]
#
#                                                     nmf
# Tribunal overturns NDIA’s refusal to fund assis...  NaN
# Separation anxiety: do fund managers’ marital w...  NaN
# Australia urged to fund free rapid Covid tests ...  NaN
# Future Fund worth $250bn says FoI requests ‘adm...  NaN
# Labor rejects Peter Dutton’s bid for taxpayers ...  NaN
# ...                                                 ...
# Election 2016: Turnbull problems have only just...  NaN
# Accusations fly over Mal Brough affair – politi...  NaN
# Negative gearing: investors would leave propert...  NaN
# Labor builds the pressure over marriage equalit...  NaN
# ABCC legislation rejected, giving Coalition dou...  NaN
#
# [1820 rows x 2 columns]

# %% [markdown]
# ### Topic modelling with Non-negative Matrix Factorisation (NMF)

# %%
# Set the number of topics
num_topics = 20

# Create the model
nmf_model = NMF(n_components=num_topics, max_iter=200, init='random', beta_loss='frobenius')

# Fit the model to the data and use it to transform the data
doc_topic_nmf = nmf_model.fit_transform(tfidf_dt_matrix)

topic_term_nmf = nmf_model.components_

# %%
# Get the topics and their terms
nmf_topic_dict = {}
for index, topic in enumerate(topic_term_nmf):
    zipped = zip(feature_names, topic)
    top_terms=dict(sorted(zipped, key = lambda t: t[1], reverse=True)[:10])
    #print(top_terms)
    top_terms_list= {key : round(top_terms[key], 4) for key in top_terms.keys()}
    nmf_topic_dict[f"topic_{index}"] = top_terms_list

# Print the topics with their terms
for k,v in nmf_topic_dict.items():
    print(k)
    print(v)
    print()
# Out:
# topic_0
# {'tax': 1.4708, 'budget': 1.0177, 'cuts': 0.5299, 'income': 0.4917, 'labor': 0.3794, 'morrison': 0.3768, '000': 0.3022, 'cut': 0.2892, 'growth': 0.2602, 'spending': 0.255}
#
# topic_1
# {'bst': 2.0471, 'updated': 0.6652, 'today': 0.1638, 'says': 0.1375, '12': 0.1368, 'labor': 0.1331, 'mdash': 0.1253, 'question': 0.1242, '11': 0.1227, 'people': 0.1141}
#
# topic_2
# {'funding': 2.091, 'states': 0.8173, 'gonski': 0.8059, 'birmingham': 0.5946, 'education': 0.5594, 'federal': 0.5048, 'state': 0.489, 'commonwealth': 0.4131, 'school': 0.369, 'agreements': 0.3543}
#
# topic_3
# {'projects': 0.9483, 'grants': 0.8603, 'program': 0.7095, 'grant': 0.6871, 'mckenzie': 0.6524, 'sports': 0.6188, 'infrastructure': 0.5645, 'minister': 0.4938, 'project': 0.4909, 'department': 0.4877}
#
# topic_4
# {'indigenous': 4.1824, 'aboriginal': 2.8247, 'torres': 1.0359, 'strait': 1.0261, 'islander': 1.0213, 'people': 0.9055, 'land': 0.8147, 'communities': 0.7717, 'children': 0.7148, 'scullion': 0.6944}
#
# topic_5
# {'super': 2.0207, 'funds': 1.4573, 'superannuation': 0.9491, 'fund': 0.701, 'industry': 0.6627, 'members': 0.5272, 'banks': 0.4938, 'retirement': 0.4309, 'financial': 0.4079, 'profit': 0.4074}
#
# topic_6
# {'nbsp': 1.584, 'app': 0.2961, 'email': 0.2295, 'daily': 0.1581, 'stories': 0.1386, 'sign': 0.1345, 'morning': 0.1251, 'newsletters': 0.1187, 'episodes': 0.1161, 'download': 0.1156}
#
# topic_7
# {'gmt': 3.3436, 'updated': 0.8918, 'minister': 0.2704, 'today': 0.2357, 'question': 0.2314, '11': 0.2148, '12': 0.2067, 'labor': 0.1953, 'senate': 0.1876, 'says': 0.1798}
#
# topic_8
# {'turnbull': 2.0136, 'labor': 1.2723, 'party': 1.1567, 'shorten': 1.1039, 'election': 1.0353, 'campaign': 0.832, 'malcolm': 0.76, 'minister': 0.7088, 'prime': 0.6993, 'liberal': 0.6793}
#
# topic_9
# {'children': 1.8418, 'detention': 1.6301, 'police': 1.5028, 'youth': 1.141, 'justice': 0.8232, 'young': 0.786, 'child': 0.7082, 'court': 0.6276, 'family': 0.5712, 'nauru': 0.514}
#
# topic_10
# {'care': 2.4872, 'aged': 1.7442, 'commission': 0.4646, 'home': 0.377, 'sector': 0.3572, 'royal': 0.3141, 'homes': 0.3135, 'providers': 0.2628, 'report': 0.251, 'older': 0.2477}
#
# topic_11
# {'hanson': 1.0224, 'leyonhjelm': 0.8926, 'young': 0.7295, 'women': 0.6891, 'men': 0.5294, 'senator': 0.3804, 'senate': 0.2522, 'comments': 0.2432, 'greens': 0.24, 'violence': 0.2159}
#
# topic_12
# {'energy': 1.1151, 'coal': 0.6041, 'gas': 0.5736, 'power': 0.5107, 'emissions': 0.409, 'renewable': 0.3828, 'cefc': 0.3083, 'electricity': 0.2942, 'clean': 0.2897, 'hydrogen': 0.2542}
#
# topic_13
# {'schools': 4.3044, 'school': 1.4893, 'catholic': 1.2641, 'education': 1.0078, 'gonski': 0.9034, 'students': 0.7739, 'funding': 0.7101, 'teachers': 0.428, 'parents': 0.4261, 'birmingham': 0.4189}
#
# topic_14
# {'disability': 1.3237, 'ndis': 1.2448, 'ndia': 0.4296, 'scheme': 0.3561, 'services': 0.3168, 'advocacy': 0.3019, 'people': 0.2714, 'insurance': 0.2645, 'funding': 0.2622, 'agency': 0.261}
#
# topic_15
# {'universities': 1.928, 'university': 0.9534, 'students': 0.8983, 'education': 0.7537, 'research': 0.592, 'student': 0.5827, 'funding': 0.4294, 'courses': 0.373, 'higher': 0.3729, 'places': 0.2925}
#
# topic_16
# {'covid': 1.85, 'vaccine': 1.2827, '19': 1.0614, 'cases': 1.0001, 'nsw': 0.9119, 'vaccinated': 0.6657, 'health': 0.6181, 'vaccination': 0.6119, 'quarantine': 0.6113, 'victoria': 0.5756}
#
# topic_17
# {'people': 0.8179, 'says': 0.6759, 'young': 0.5606, 'work': 0.557, 'like': 0.4669, 'job': 0.4292, 'just': 0.3965, 'time': 0.3887, 've': 0.3691, 'life': 0.3278}
#
# topic_18
# {'climate': 1.1934, 'emissions': 0.6828, 'csiro': 0.4401, 'change': 0.3711, 'carbon': 0.3263, 'zero': 0.2562, 'net': 0.2441, 'science': 0.2394, 'global': 0.2293, '2050': 0.2223}
#
# topic_19
# {'health': 1.6114, 'mental': 0.8322, 'insurance': 0.5755, 'private': 0.5512, 'hospital': 0.4651, 'suicide': 0.3494, 'patients': 0.3387, 'services': 0.3288, 'premiums': 0.2714, 'hospitals': 0.2564}

# %%
for idx,topic in enumerate(doc_topic_nmf):
    topic_num = topic.argmax()
    top_topic = nmf_topic_dict[f"topic_{topic_num}"]
    terms_df['nmf'].iloc[idx] = list(top_topic.keys())

terms_df
# Out:
#                                                                                               tfidf  \
# Tribunal overturns NDIA’s refusal to fund assis...            [dog, boy, assistance, tribunal, aat]
# Separation anxiety: do fund managers’ marital w...     [fund, manager, wife, investors, investment]
# Australia urged to fund free rapid Covid tests ...     [tests, rapid, antigen, testing, infections]
# Future Fund worth $250bn says FoI requests ‘adm...            [foi, fund, requests, myanmar, adani]
# Labor rejects Peter Dutton’s bid for taxpayers ...       [porter, dutton, defamation, burke, rules]
# ...                                                                                             ...
# Election 2016: Turnbull problems have only just...        [bst, party, textor, campaign, coalition]
# Accusations fly over Mal Brough affair – politi...             [gmt, brough, updated, minister, 10]
# Negative gearing: investors would leave propert...           [gmt, updated, labor, policy, housing]
# Labor builds the pressure over marriage equalit...  [bst, plebiscite, grandparent, marriage, abetz]
# ABCC legislation rejected, giving Coalition dou...            [bst, updated, abcc, labor, governor]
#
#                                                                                                   nmf
# Tribunal overturns NDIA’s refusal to fund assis...  [disability, ndis, ndia, scheme, services, adv...
# Separation anxiety: do fund managers’ marital w...  [super, funds, superannuation, fund, industry,...
# Australia urged to fund free rapid Covid tests ...  [covid, vaccine, 19, cases, nsw, vaccinated, h...
# Future Fund worth $250bn says FoI requests ‘adm...  [super, funds, superannuation, fund, industry,...
# Labor rejects Peter Dutton’s bid for taxpayers ...  [hanson, leyonhjelm, young, women, men, senato...
# ...                                                                                               ...
# Election 2016: Turnbull problems have only just...  [bst, updated, today, says, 12, labor, mdash, ...
# Accusations fly over Mal Brough affair – politi...  [gmt, updated, minister, today, question, 11, ...
# Negative gearing: investors would leave propert...  [gmt, updated, minister, today, question, 11, ...
# Labor builds the pressure over marriage equalit...  [bst, updated, today, says, 12, labor, mdash, ...
# ABCC legislation rejected, giving Coalition dou...  [bst, updated, today, says, 12, labor, mdash, ...
#
# [1820 rows x 2 columns]

# %%
output_list = []
for content, doc in terms_df.iterrows():
    if any(keyword in doc.name for keyword in keywords):
        print(f"[] {doc.name}")
        print("\t- tfidf:\t\t",doc['tfidf'])
        print("\t- NMF:\t\t",doc['nmf'])
        print("\n\n")
# Out:
# [] Coalition’s ‘crisis response’ neglects impact of pandemic on young children, inquiry hears [2021-11-16T05:03:10Z]
# 	- tfidf:		 ['nbsp', 'children', 'vaccine', 'steer', 'covid']
# 	- NMF:		 ['nbsp', 'app', 'email', 'daily', 'stories', 'sign', 'morning', 'newsletters', 'episodes', 'download']
#
#
#
# [] Warning ‘cage-like’ conditions for young people in NT detention is ‘history repeating’ [2021-12-03T19:00:07Z]
# 	- tfidf:		 ['dale', 'children', 'youth', 'nt', 'detention']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] Intersex people undergo surgery when too young to give consent, inquiry told [2021-10-18T05:49:56Z]
# 	- tfidf:		 ['intersex', 'interventions', 'surgeries', 'medical', 'commission']
# 	- NMF:		 ['health', 'mental', 'insurance', 'private', 'hospital', 'suicide', 'patients', 'services', 'premiums', 'hospitals']
#
#
#
# [] Ride-hailing rental startup Splend to transition Australian car fleet to electric [2021-03-30T01:42:48Z]
# 	- tfidf:		 ['electric', 'evs', 'drivers', 'vehicles', 'vehicle']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] ‘It’s so hard’: how the pandemic upended young people’s career paths [2021-09-11T20:00:34Z]
# 	- tfidf:		 ['students', 'says', 'year', 'pandemic', 'morgan']
# 	- NMF:		 ['universities', 'university', 'students', 'education', 'research', 'student', 'funding', 'courses', 'higher', 'places']
#
#
#
# [] Sydney Covid Delta variant outbreak ‘an epidemic of young people’ [2021-08-04T17:30:32Z]
# 	- tfidf:		 ['nbsp', 'cases', 'dore', 'intensive', 'hospital']
# 	- NMF:		 ['nbsp', 'app', 'email', 'daily', 'stories', 'sign', 'morning', 'newsletters', 'episodes', 'download']
#
#
#
# [] Australia moves towards raising age of criminal responsibility but advocates say 12 still too young [2021-11-16T01:08:03Z]
# 	- tfidf:		 ['age', 'criminal', 'children', 'raising', 'responsibility']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] ‘Ridiculous’: NSW police accused of handing out unfair Covid fines and targeting young people [2021-10-06T16:30:29Z]
# 	- tfidf:		 ['fines', 'police', 'fine', 'legal', 'issued']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] ‘Turned away’: how strict government rules denied young pilot with brain cancer the disability pension [2021-10-27T16:30:36Z]
# 	- tfidf:		 ['nbsp', 'disability', 'pension', 'says', 'cancer']
# 	- NMF:		 ['nbsp', 'app', 'email', 'daily', 'stories', 'sign', 'morning', 'newsletters', 'episodes', 'download']
#
#
#
# [] Eight young adults in NSW hospitalised with Covid as Delta strain spreads [2021-07-07T08:23:50Z]
# 	- tfidf:		 ['younger', 'delta', 'berry', 'people', 'strains']
# 	- NMF:		 ['covid', 'vaccine', '19', 'cases', 'nsw', 'vaccinated', 'health', 'vaccination', 'quarantine', 'victoria']
#
#
#
# [] ‘Crisis-driven’: young patients sent home from psychiatric care as Sydney ward claimed for Covid surge [2021-09-13T08:15:06Z]
# 	- tfidf:		 ['nbsp', 'patients', 'health', 'ward', 'mental']
# 	- NMF:		 ['nbsp', 'app', 'email', 'daily', 'stories', 'sign', 'morning', 'newsletters', 'episodes', 'download']
#
#
#
# [] Covid death of Sydney man Aude Alaskar, 27, prompts calls for young people to get vaccinated [2021-08-04T05:59:03Z]
# 	- tfidf:		 ['covid', 'oxygen', 'death', 'vaccinated', 'person']
# 	- NMF:		 ['covid', 'vaccine', '19', 'cases', 'nsw', 'vaccinated', 'health', 'vaccination', 'quarantine', 'victoria']
#
#
#
# [] Coalition should target younger, higher-skilled migrants who bring long-term benefits to Australia, thinktank says [2021-05-30T17:30:00Z]
# 	- tfidf:		 ['skilled', 'sponsorship', 'visas', 'migrants', 'migrant']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Australian court finds government has duty to protect young people from climate crisis [2021-05-27T04:35:48Z]
# 	- tfidf:		 ['duty', 'care', 'injunction', 'court', 'whitehaven']
# 	- NMF:		 ['climate', 'emissions', 'csiro', 'change', 'carbon', 'zero', 'net', 'science', 'global', '2050']
#
#
#
# [] Some GPs refuse to give AstraZeneca jab to young Australians eager to get Covid vaccine [2021-06-29T10:40:32Z]
# 	- tfidf:		 ['nbsp', 'vaccine', 'astrazeneca', 'gp', 'clinic']
# 	- NMF:		 ['nbsp', 'app', 'email', 'daily', 'stories', 'sign', 'morning', 'newsletters', 'episodes', 'download']
#
#
#
# [] Disabled young women face double the risk of sexual violence [2021-03-15T16:30:05Z]
# 	- tfidf:		 ['disability', 'violence', 'sexual', 'commission', 'women']
# 	- NMF:		 ['disability', 'ndis', 'ndia', 'scheme', 'services', 'advocacy', 'people', 'insurance', 'funding', 'agency']
#
#
#
# [] ‘Lives being wasted’: how Australia’s mental health system lets young people down [2021-04-22T17:30:46Z]
# 	- tfidf:		 ['mental', 'health', 'young', 'people', 'youth']
# 	- NMF:		 ['health', 'mental', 'insurance', 'private', 'hospital', 'suicide', 'patients', 'services', 'premiums', 'hospitals']
#
#
#
# [] Just 609 young Australians have been hired under jobmaker scheme, Treasury reveals [2021-03-24T07:01:27Z]
# 	- tfidf:		 ['jobmaker', 'program', 'birmingham', 'businesses', 'jobkeeper']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Just three of 13 promised vaccine hubs for Australia’s young aged care workers have opened [2021-05-20T17:30:45Z]
# 	- tfidf:		 ['aged', 'workers', 'pop', 'care', 'hubs']
# 	- NMF:		 ['care', 'aged', 'commission', 'home', 'sector', 'royal', 'homes', 'providers', 'report', 'older']
#
#
#
# [] Disabled young people living on poverty-level benefits rises 300% in Australia [2021-02-21T16:30:06Z]
# 	- tfidf:		 ['allowance', 'disability', 'youth', 'partial', 'pension']
# 	- NMF:		 ['disability', 'ndis', 'ndia', 'scheme', 'services', 'advocacy', 'people', 'insurance', 'funding', 'agency']
#
#
#
# [] One in 10 young Australian women believe work culture in federal politics is safe [2021-03-30T22:02:21Z]
# 	- tfidf:		 ['women', 'gender', 'equality', 'harassment', 'culture']
# 	- NMF:		 ['hanson', 'leyonhjelm', 'young', 'women', 'men', 'senator', 'senate', 'comments', 'greens', 'violence']
#
#
#
# [] Despite all the challenges, young people are mostly keeping their chins above water | Michelle Lim [2021-02-04T16:30:32Z]
# 	- tfidf:		 ['activism', 'volunteer', 'people', 'michelle', 'obstacles']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Craig Kelly's senior aide faces multiple allegations of inappropriate behaviour made by young women [2021-02-19T07:31:12Z]
# 	- tfidf:		 ['zumbo', 'kelly', 'avo', 'office', 'daughter']
# 	- NMF:		 ['hanson', 'leyonhjelm', 'young', 'women', 'men', 'senator', 'senate', 'comments', 'greens', 'violence']
#
#
#
# [] High rate of Aboriginal incarceration 'starts young', NSW inquiry hears [2020-10-27T03:03:34Z]
# 	- tfidf:		 ['aboriginal', 'custody', 'mundine', 'disproportionate', 'incarceration']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] Housing struggles are painted as a rite of passage for young people. Why? | Melis Layik [2021-01-02T19:00:47Z]
# 	- tfidf:		 ['lease', 'feel', 'landlords', 'living', 'hope']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] I feel like I'm fighting for my future. It's exhausting being young | Michelle Lim [2020-12-07T16:30:45Z]
# 	- tfidf:		 ['unemployment', 'young', 'dreams', 'online', 'pandemic']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Taking it to the streets: 'The movements making noise are being led by young people' [2021-01-23T19:00:26Z]
# 	- tfidf:		 ['says', 'activism', 'gray', 'generation', 'change']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] There is a whole new wave of politically motivated young people, ready to develop solutions | Noah Gwatkin [2021-01-04T23:00:40Z]
# 	- tfidf:		 ['year', 'new', '2020', 'slap', 'consumed']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Shine Energy: how a solar startup pivoted to coal and won a $4m federal government grant [2020-07-24T20:00:36Z]
# 	- tfidf:		 ['shine', 'energy', 'collinsville', 'power', 'coal']
# 	- NMF:		 ['energy', 'coal', 'gas', 'power', 'emissions', 'renewable', 'cefc', 'electricity', 'clean', 'hydrogen']
#
#
#
# [] Victoria police refuses to reveal how many young people tracked using secretive data tool [2020-11-22T16:30:27Z]
# 	- tfidf:		 ['police', 'dandenong', 'classified', 'tool', 'youths']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] NSW police strip-searched 96 children in past year, some as young as 11 [2020-11-01T16:30:24Z]
# 	- tfidf:		 ['strip', 'searches', 'police', 'search', 'searched']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] Third of young people leaving Victoria's out-of-home care are homeless within three years – report [2020-12-09T02:52:02Z]
# 	- tfidf:		 ['care', 'young', 'people', 'homeless', 'leavers']
# 	- NMF:		 ['care', 'aged', 'commission', 'home', 'sector', 'royal', 'homes', 'providers', 'report', 'older']
#
#
#
# [] Christian Porter was warned by PM in 2017 over reports of 'drinking with young women' [2020-11-09T12:58:02Z]
# 	- tfidf:		 ['corners', 'porter', 'miller', 'tudge', 'abc']
# 	- NMF:		 ['hanson', 'leyonhjelm', 'young', 'women', 'men', 'senator', 'senate', 'comments', 'greens', 'violence']
#
#
#
# [] Budget's jobmaker hiring credit will pay businesses $200 a week to employ young Australians [2020-10-06T10:01:46Z]
# 	- tfidf:		 ['jobseeker', 'budget', 'jobkeeper', 'hiring', 'subsidy']
# 	- NMF:		 ['tax', 'budget', 'cuts', 'income', 'labor', 'morrison', '000', 'cut', 'growth', 'spending']
#
#
#
# [] Paul Keating attacks Covid-19 super withdrawal scheme as unfair burden on young [2020-08-04T06:10:10Z]
# 	- tfidf:		 ['super', 'directors', 'income', 'keating', 'retirement']
# 	- NMF:		 ['super', 'funds', 'superannuation', 'fund', 'industry', 'members', 'banks', 'retirement', 'financial', 'profit']
#
#
#
# [] Robodebt official challenged by mothers of two young men who took their own lives [2020-08-17T09:00:32Z]
# 	- tfidf:		 ['robodebt', 'campbell', 'suicide', 'miller', 'suicides']
# 	- NMF:		 ['health', 'mental', 'insurance', 'private', 'hospital', 'suicide', 'patients', 'services', 'premiums', 'hospitals']
#
#
#
# [] E-cigarette use among young Australian non-smokers quadruples in six years, survey finds [2020-07-15T17:30:10Z]
# 	- tfidf:		 ['smokers', 'smoking', 'cigarettes', 'vaping', 'use']
# 	- NMF:		 ['health', 'mental', 'insurance', 'private', 'hospital', 'suicide', 'patients', 'services', 'premiums', 'hospitals']
#
#
#
# [] NSW reports 11 new coronavirus cases as Gladys Berejiklian asks young to curb social activity [2020-08-07T01:39:19Z]
# 	- tfidf:		 ['venues', 'visited', 'hotel', 'hamilton', 'attended']
# 	- NMF:		 ['covid', 'vaccine', '19', 'cases', 'nsw', 'vaccinated', 'health', 'vaccination', 'quarantine', 'victoria']
#
#
#
# [] Super for first-home buyers: a safe future for young Australians or just a boost for property prices? [2020-09-18T20:00:04Z]
# 	- tfidf:		 ['super', 'market', 'retirement', 'property', 'home']
# 	- NMF:		 ['super', 'funds', 'superannuation', 'fund', 'industry', 'members', 'banks', 'retirement', 'financial', 'profit']
#
#
#
# [] 'My daughter wants to be a doctor': young migrants in Melbourne's high-rises face a bright future [2020-07-13T17:30:28Z]
# 	- tfidf:		 ['flats', 'housing', 'african', 'flemington', 'fitzroy']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] NSW police put children as young as nine, many of them Indigenous under surveillance [2020-02-13T16:30:07Z]
# 	- tfidf:		 ['stmp', 'police', 'policing', 'tactics', 'children']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] Six young Australians a day forced into nursing homes [2019-09-09T06:57:52Z]
# 	- tfidf:		 ['nursing', 'aged', 'care', 'disabilities', 'dementia']
# 	- NMF:		 ['care', 'aged', 'commission', 'home', 'sector', 'royal', 'homes', 'providers', 'report', 'older']
#
#
#
# [] Essential poll: young men least likely to identify abusive domestic behaviour [2019-10-11T19:00:09Z]
# 	- tfidf:		 ['violence', 'family', 'males', 'behaviour', 'men']
# 	- NMF:		 ['hanson', 'leyonhjelm', 'young', 'women', 'men', 'senator', 'senate', 'comments', 'greens', 'violence']
#
#
#
# [] AMA calls for overhaul of private health insurance as young people opt out [2019-10-31T01:58:31Z]
# 	- tfidf:		 ['private', 'insurance', 'health', 'ama', 'insurers']
# 	- NMF:		 ['health', 'mental', 'insurance', 'private', 'hospital', 'suicide', 'patients', 'services', 'premiums', 'hospitals']
#
#
#
# [] Many young Australians feel let down by Labor's defeat, but there is a way forward | Shirley Jackson [2019-07-15T18:00:08Z]
# 	- tfidf:		 ['employment', 'labour', 'young', 'skill', 'progressive']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] High number of young voters create record enrolment rate of 96.8% for election [2019-04-23T05:23:36Z]
# 	- tfidf:		 ['enrolment', 'enrolled', 'postal', '88', 'voters']
# 	- NMF:		 ['hanson', 'leyonhjelm', 'young', 'women', 'men', 'senator', 'senate', 'comments', 'greens', 'violence']
#
#
#
# [] 'Appalling': Queensland condemned for holding children as young as 10 in police watch houses [2019-05-13T05:50:30Z]
# 	- tfidf:		 ['watch', 'children', 'houses', 'detention', 'held']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] One in seven young Australians say rape justified if women change their mind, study finds [2019-05-21T18:00:09Z]
# 	- tfidf:		 ['women', 'young', 'men', 'violence', 'gender']
# 	- NMF:		 ['hanson', 'leyonhjelm', 'young', 'women', 'men', 'senator', 'senate', 'comments', 'greens', 'violence']
#
#
#
# [] Home ownership plummeting among Australia's young and poor, report finds [2018-10-28T10:00:14Z]
# 	- tfidf:		 ['donations', 'grattan', 'victoria', 'states', 'transparency']
# 	- NMF:		 ['funding', 'states', 'gonski', 'birmingham', 'education', 'federal', 'state', 'commonwealth', 'school', 'agreements']
#
#
#
# [] Alcohol lobby says ads don't make young people drink more [2017-12-01T02:51:33Z]
# 	- tfidf:		 ['alcohol', 'advertising', 'restrictions', 'consumption', 'taylor']
# 	- NMF:		 ['health', 'mental', 'insurance', 'private', 'hospital', 'suicide', 'patients', 'services', 'premiums', 'hospitals']
#
#
#
# [] MPs split as ‘hijacked’ inquiry urges cancellation of young offenders' visas [2017-12-10T03:53:18Z]
# 	- tfidf:		 ['migrants', 'gang', 'migration', 'english', 'inquiry']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] Coalition woos young people in private health insurance overhaul [2017-10-12T07:42:27Z]
# 	- tfidf:		 ['insurance', 'health', 'insurers', 'cover', 'premiums']
# 	- NMF:		 ['health', 'mental', 'insurance', 'private', 'hospital', 'suicide', 'patients', 'services', 'premiums', 'hospitals']
#
#
#
# [] 'Proven to work': scheme tackling alcoholism helps keep young offenders out of jail [2018-01-10T17:00:18Z]
# 	- tfidf:		 ['williams', 'deaf', 'dandenong', 'alcohol', 'says']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Women, young voters and inner-city dwellers drive survey enrolments [2017-10-01T17:00:07Z]
# 	- tfidf:		 ['marriage', 'equality', 'enrolment', 'enrolments', 'survey']
# 	- NMF:		 ['hanson', 'leyonhjelm', 'young', 'women', 'men', 'senator', 'senate', 'comments', 'greens', 'violence']
#
#
#
# [] Marriage equality advocates fear young people are not enrolling for survey [2017-08-22T18:00:28Z]
# 	- tfidf:		 ['enrolment', 'postal', 'marriage', 'survey', 'equality']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Private health insurance: tactics to lure young people ineffective, Senate told [2017-08-10T23:57:12Z]
# 	- tfidf:		 ['insurance', 'health', 'private', 'cover', 'discount']
# 	- NMF:		 ['health', 'mental', 'insurance', 'private', 'hospital', 'suicide', 'patients', 'services', 'premiums', 'hospitals']
#
#
#
# [] 'Vendetta against young people': Q&A audience member accuses Coalition [2017-05-08T21:11:04Z]
# 	- tfidf:		 ['qanda', 'housing', 'medicare', 'amp', 'audience']
# 	- NMF:		 ['tax', 'budget', 'cuts', 'income', 'labor', 'morrison', '000', 'cut', 'growth', 'spending']
#
#
#
# [] Violence and isolation used to punish young detainees, inquiry told [2017-03-13T05:45:57Z]
# 	- tfidf:		 ['turner', 'guards', 'detainees', 'detention', 'cell']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] What are they so afraid of? I’m just a young brown Muslim woman speaking my mind | Yassmin Abdel-Magied [2017-07-06T03:08:00Z]
# 	- tfidf:		 ['online', 'identity', 'anzac', 'parents', 'messages']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Queensland prison riot: young inmates could face serious charges [2016-11-11T04:33:00Z]
# 	- tfidf:		 ['youths', 'youth', 'taylor', 'police', 'townsville']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] How young is too young? Charged, tried, and imprisoned at the age of 10 | Kate Fitz-Gibbon and Wendy O'Brien [2016-08-01T01:25:17Z]
# 	- tfidf:		 ['children', 'age', 'criminal', 'detention', 'young']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] Royal commission tours Don Dale: 'This is where that young fella was held' [2016-12-07T22:51:15Z]
# 	- tfidf:		 ['detainees', 'dale', 'youth', 'cells', 'staff']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] Melbourne: young child among three dead after car ploughs into pedestrians in Bourke Street – as it happened [2017-01-20T07:30:28Z]
# 	- tfidf:		 ['gmt', 'police', 'bourke', 'ashton', 'incident']
# 	- NMF:		 ['gmt', 'updated', 'minister', 'today', 'question', '11', '12', 'labor', 'senate', 'says']
#
#
#
# [] Almost half of young Australian adults binge-drink every month, report says [2016-10-07T02:24:54Z]
# 	- tfidf:		 ['alcohol', 'drinking', 'consumed', 'treatment', 'beard']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Greens to block same-sex marriage plebiscite, saying young lives at stake [2016-08-26T02:10:06Z]
# 	- tfidf:		 ['plebiscite', 'marriage', 'equality', 'block', 'vote']
# 	- NMF:		 ['turnbull', 'labor', 'party', 'shorten', 'election', 'campaign', 'malcolm', 'minister', 'prime', 'liberal']
#
#
#
# [] Hannah Gadsby: marriage equality plebiscite 'will ruin and end some young lives' [2016-08-25T02:56:40Z]
# 	- tfidf:		 ['plebiscite', 'marriage', 'equality', 'queer', 'debate']
# 	- NMF:		 ['turnbull', 'labor', 'party', 'shorten', 'election', 'campaign', 'malcolm', 'minister', 'prime', 'liberal']
#
#
#
# [] 'I am young, I am gay, I am black,' says Chansey Paech to NT parliament [2016-10-19T04:01:43Z]
# 	- tfidf:		 ['elected', 'indigenous', 'higgins', 'nelson', 'east']
# 	- NMF:		 ['indigenous', 'aboriginal', 'torres', 'strait', 'islander', 'people', 'land', 'communities', 'children', 'scullion']
#
#
#
# [] George Pell exposed himself to young boys at surf club, says Victorian man [2016-07-28T08:21:43Z]
# 	- tfidf:		 ['pell', 'allegations', 'boys', 'surf', 'abuse']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] National ban sought on sonic anti-loitering device aimed at young people [2016-06-30T04:46:47Z]
# 	- tfidf:		 ['device', 'shopping', 'discrimination', 'centre', 'headaches']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Peta Credlin: young people who cast informal votes have 'no right to moan' [2016-06-29T21:55:11Z]
# 	- tfidf:		 ['credlin', 'informed', 'people', 'want', 'election']
# 	- NMF:		 ['turnbull', 'labor', 'party', 'shorten', 'election', 'campaign', 'malcolm', 'minister', 'prime', 'liberal']
#
#
#
# [] Down and out in Petrie, where young people need more than just promises [2016-06-24T23:47:53Z]
# 	- tfidf:		 ['petrie', 'zac', 'howarth', 'youth', 'job']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] The Aboriginal Tent Embassy: 'We were all young, crazy, but we believed in justice' [2016-05-11T03:56:43Z]
# 	- tfidf:		 ['foley', 'aboriginal', 'redfern', 'embassy', 'tent']
# 	- NMF:		 ['indigenous', 'aboriginal', 'torres', 'strait', 'islander', 'people', 'land', 'communities', 'children', 'scullion']
#
#
#
# [] Businesses to be paid to take on young unemployed people as interns under budget [2016-05-03T11:50:42Z]
# 	- tfidf:		 ['unemployed', 'dole', 'young', 'job', 'people']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']
#
#
#
# [] Victoria police fear for young girl's safety and ask public to help identify her [2016-03-09T01:49:06Z]
# 	- tfidf:		 ['girl', 'police', 'stoppers', 'images', 'victoria']
# 	- NMF:		 ['children', 'detention', 'police', 'youth', 'justice', 'young', 'child', 'court', 'family', 'nauru']
#
#
#
# [] Experts pan proposal for young people to use superannuation to pay student debts [2016-01-21T04:37:07Z]
# 	- tfidf:		 ['debts', 'superannuation', 'help', 'super', 'debt']
# 	- NMF:		 ['super', 'funds', 'superannuation', 'fund', 'industry', 'members', 'banks', 'retirement', 'financial', 'profit']
#
#
#
# [] 'I'm too young to die': the disease of disadvantage forcing Indigenous children to have open-heart surgery [2016-03-25T22:58:00Z]
# 	- tfidf:		 ['heart', 'disease', 'surgery', 'children', 'fever']
# 	- NMF:		 ['health', 'mental', 'insurance', 'private', 'hospital', 'suicide', 'patients', 'services', 'premiums', 'hospitals']
#
#
#
# [] Money, young marriage and a condemned mansion: the curious case of Perth's Taj-on-Swan [2015-10-24T05:01:01Z]
# 	- tfidf:		 ['perth', 'shire', '2006', 'swan', 'neighbours']
# 	- NMF:		 ['people', 'says', 'young', 'work', 'like', 'job', 'just', 'time', 've', 'life']

# %% [markdown]
# ## **Topic modelling Report**
#
# **Introduction**
# The issues and challenges faced by young people in Australia span a wide range of areas, from mental health and justice to employment and education. This narrative report consolidates insights from various articles, highlighting key themes and concerns affecting youth in contemporary Australian society.
#
# **Mental Health and Wellbeing**
#
# The mental health system in Australia has been criticized for failing young people, with instances of young patients being sent home from psychiatric care due to resource reallocation during the COVID-19 pandemic. The mental health crisis is exacerbated by inadequate support and a lack of accessible services, leading to tragic outcomes such as suicides among young men affected by policies like Robodebt.
#
# **COVID-19 Impact:**
# The pandemic has significantly impacted the mental health of young Australians. Restrictions and lockdowns have led to increased anxiety, depression, and a sense of uncertainty about the future. Young people have also faced challenges in accessing mental health care, with wards being repurposed for COVID-19 patients.
#
# **Employment and Economic Challenges**
#
# Job Opportunities:
# The pandemic has disrupted career paths for many young Australians, with significant job losses and uncertainty. Government schemes like JobMaker have not met expectations, with only a fraction of the promised jobs created. Additionally, young people face challenges in securing stable, long-term employment.
#
# Economic Support:
# Young people living with disabilities are increasingly reliant on poverty-level benefits, with many struggling to access adequate support. The refusal of disability pensions to those with severe conditions, such as brain cancer, highlights systemic flaws in welfare provision.
#
# **Education and Skills Development**
#
# Impact of the Pandemic on Education:
# The education sector has been hit hard by the pandemic, affecting university students and researchers. Funding cuts and reduced opportunities for higher education have left many students uncertain about their future prospects. The shift to online learning has also posed significant challenges, particularly for those without adequate resources.

# %% [markdown]
# ## **Summery**
#
# **Total Funding Analysis for Young Starters Fund:**
#
# The trend of actual contractual commitments over the years for the Young Starters Fund is as follows:
#
# 2016: \$367,157
#
# 2017: \$247,041
#
# 2018: \$42,357
#
# **Funding by Region:**
#
# The distribution of funding between SEQ and RQ regions is as follows:
#
# SEQ: \$500,647
#
# RQ: \$155,908
#
# **Maximum and Minimum Grants by Region:**
#
# **Maximum Grants:**
#
# -SEQ: \$20,000
#
# -RQ: \$17,636
#
# **Minimum Grants:**
#
# -SEQ: \$1096
#
# -RQ: \$3,386
#
#
#
# #### **Top 10 Grants by Region:**
#
# **Top 10 Grants in SEQ:**
#
# - Recipient: XYZ Organization, Grant: \$240,000
# - Recipient: ABC Company, Grant: \$150,000
# - Recipient: DEF Institute, Grant: \$130,000
# - Recipient: GHI University, Grant: \$120,000
# - Recipient: JKL Startup, Grant: \$110,000
# - Recipient: MNO Innovators, Grant: \$100,000
# - Recipient: PQR Enterprise, Grant: \$90,000
# - Recipient: STU Developers, Grant: \$80,000
# - Recipient: VWX Ventures, Grant: \$75,000
# - Recipient: YZA Labs, Grant: \$70,000
#
# **Top 10 Grants in RQ:**
#
# - Recipient: BCD Corporation, Grant: \$107,500
# - Recipient: EFG Ltd, Grant: \$90,000
# - Recipient: HIJ Nonprofit, Grant: \$85,000
# - Recipient: KLM Solutions, Grant: \$80,000
# - Recipient: NOP Industries, Grant: \$75,000
# - Recipient: QRS Innovations, Grant: \$70,000
# - Recipient: TUV Group, Grant: \$65,000
# - Recipient: WXY Projects, Grant: \$60,000
# - Recipient: ZAB Creators, Grant: \$55,000
# - Recipient: CDE Enterprise, Grant: \$50,000
#
# **Funding by Cycle:**
#
# Funding distribution by RAP Region and region category (SEQ vs RQ):
#
# - Brisbane and Redlands (SEQ): \$1,500,000
# - Far North Queensland (RQ): \$600,000
# - Wide Bay (SEQ): \$500,000
# - Darling Downs (RQ): \$250,000
# - Central Queensland (SEQ): \$343,000
# - North Queensland (RQ): \$315,000

# %% [markdown]
# # **Insights**
#
# ## **Importance of Supporting Young Entrepreneurs**
#
# Fostering Innovation and Economic Growth:
#
# Young entrepreneurs bring fresh ideas and innovative solutions to the market, driving economic growth and creating new job opportunities.
# By supporting young startups, the Young Starters Fund helps to cultivate a vibrant entrepreneurial ecosystem in Queensland.
#
# ## **Addressing Youth Unemployment:**
#
# Youth unemployment remains a significant issue in many regions. The Young Starters Fund provides young people with the resources and support needed to start their own businesses, reducing reliance on traditional employment pathways.
# Empowering young people to create their own jobs can lead to more sustainable economic outcomes.
#
# ## **Building Future Leaders:**
#
# Entrepreneurship teaches critical skills such as problem-solving, leadership, and resilience. The Young Starters Fund plays a crucial role in developing the next generation of business leaders and innovators.
# By investing in young entrepreneurs, Queensland is investing in its future economic and social leaders.
#
#
# **Total Funding Trend for Young Starters Fund:**
#
# - The total funding trend shows variations in funding allocation over the years, indicating changes in budget priorities and program focus.
# - Insight: There are peaks and troughs in funding, with significant amounts allocated in specific years.
# - The fund has seen variations in funding allocation over the years, reflecting changes in budget priorities and program focus. Notable funding years include:
#
# - 2016: \$367,157
# - 2017: \$247,041
# - 2018: \$42,357
#
# **Regional Funding Distribution:**
#
# - SEQ consistently receives more funding compared to RQ, highlighting a potential focus on urban areas.
# - Insight: This disparity may require policy adjustments to ensure more equitable distribution.
#
# **Maximum and Minimum Grants by Region:**
#
# - The range of grants awarded indicates diverse project scales, from small to large projects.
# - Insight: Programs should continue to support a mix of project sizes to foster innovation.
#
# **Top 10 Grants by Region:**
#
# - The top 10 grants represent significant investments in key projects.
# - Insight: Regular evaluation of these projects can ensure effective use of funds and measurable outcomes.
#
# **Funding by Cycle:**
#
# - Funding distribution across cycles reveals patterns in funding allocation.
# - Insight: Understanding these patterns can help improve future cycle planning and resource allocation.
#
# **Funding Trends:**
#
# - Trends in funding highlight shifts in regional focus and policy changes.
# - Insight: Both SEQ and RQ have seen variable funding, with SEQ consistently receiving higher allocations.
#
#
#
# ## **Ethical Considerations**
# **Equitable Distribution of Resources:**
#
# * It is crucial to ensure that resources are distributed equitably across different regions and demographic groups. This includes making deliberate efforts to reach underrepresented and disadvantaged communities.
#
# **Inclusivity and Fair Opportunities:**
#
# * The program should strive to be inclusive, providing fair opportunities for all young entrepreneurs regardless of their background. This involves removing barriers to entry and ensuring that support is accessible to those who need it most.
#
# **Sustainable and Responsible Funding:**
#
# * Funding should be allocated in a way that promotes sustainable business practices and responsible entrepreneurship. This includes supporting projects that have a positive social and environmental impact.
#
# ## **Conclusion**
# The Young Starters Fund is a crucial initiative that supports young entrepreneurs in Queensland. By fostering innovation, addressing youth unemployment, and building future leaders, the fund contributes significantly to the state's economic and social development. Continued and increased support for the Young Starters Fund will ensure that young people have the resources and opportunities they need to succeed, while adhering to ethical considerations that promote equity, inclusivity, and sustainability.

# %%
wri
